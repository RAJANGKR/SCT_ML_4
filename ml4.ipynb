# %%
pip install "tensorflow==2.15.0"
# Out:
# Collecting tensorflow==2.15.0
#   Downloading tensorflow-2.15.0-cp310-cp310-macosx_12_0_arm64.whl.metadata (3.6 kB)
# Collecting tensorflow-macos==2.15.0 (from tensorflow==2.15.0)
#   Downloading tensorflow_macos-2.15.0-cp310-cp310-macosx_12_0_arm64.whl.metadata (4.2 kB)
# Collecting absl-py>=1.0.0 (from tensorflow-macos==2.15.0->tensorflow==2.15.0)
#   Downloading absl_py-2.4.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow-macos==2.15.0->tensorflow==2.15.0)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=23.5.26 (from tensorflow-macos==2.15.0->tensorflow==2.15.0)
#   Downloading flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow-macos==2.15.0->tensorflow==2.15.0)
#   Downloading gast-0.7.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow-macos==2.15.0->tensorflow==2.15.0)
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting h5py>=2.9.0 (from tensorflow-macos==2.15.0->tensorflow==2.15.0)
#   Downloading h5py-3.16.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (3.0 kB)
# Collecting libclang>=13.0.0 (from tensorflow-macos==2.15.0->tensorflow==2.15.0)
#   Using cached libclang-18.1.1-1-py2.py3-none-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Collecting ml-dtypes~=0.2.0 (from tensorflow-macos==2.15.0->tensorflow==2.15.0)
#   Downloading ml_dtypes-0.2.0-cp310-cp310-macosx_10_9_universal2.whl.metadata (20 kB)
# Collecting numpy<2.0.0,>=1.23.5 (from tensorflow-macos==2.15.0->tensorflow==2.15.0)
#   Using cached numpy-1.26.4-cp310-cp310-macosx_11_0_arm64.whl.metadata (61 kB)
# Collecting opt-einsum>=2.3.2 (from tensorflow-macos==2.15.0->tensorflow==2.15.0)
#   Using cached opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in /Users/rjn_g/Library/Python/3.10/lib/python/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15.0) (25.0)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow-macos==2.15.0->tensorflow==2.15.0)
#   Downloading protobuf-4.25.9-cp37-abi3-macosx_10_9_universal2.whl.metadata (541 bytes)
# Requirement already satisfied: setuptools in /opt/homebrew/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15.0) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in /Users/rjn_g/Library/Python/3.10/lib/python/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15.0) (1.17.0)
# Collecting termcolor>=1.1.0 (from tensorflow-macos==2.15.0->tensorflow==2.15.0)
#   Downloading termcolor-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/rjn_g/Library/Python/3.10/lib/python/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15.0) (4.15.0)
# Collecting wrapt<1.15,>=1.11.0 (from tensorflow-macos==2.15.0->tensorflow==2.15.0)
#   Downloading wrapt-1.14.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.5 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow-macos==2.15.0->tensorflow==2.15.0)
#   Using cached tensorflow_io_gcs_filesystem-0.37.1-cp310-cp310-macosx_12_0_arm64.whl.metadata (14 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow-macos==2.15.0->tensorflow==2.15.0)
#   Downloading grpcio-1.81.1-cp310-cp310-macosx_11_0_universal2.whl.metadata (3.7 kB)
# Collecting tensorboard<2.16,>=2.15 (from tensorflow-macos==2.15.0->tensorflow==2.15.0)
#   Downloading tensorboard-2.15.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting tensorflow-estimator<2.16,>=2.15.0 (from tensorflow-macos==2.15.0->tensorflow==2.15.0)
#   Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting keras<2.16,>=2.15.0 (from tensorflow-macos==2.15.0->tensorflow==2.15.0)
#   Downloading keras-2.15.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/homebrew/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15.0) (2.43.0)
# Collecting google-auth-oauthlib<2,>=0.5 (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15.0)
#   Downloading google_auth_oauthlib-1.4.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting markdown>=2.6.8 (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15.0)
#   Downloading markdown-3.10.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/homebrew/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15.0) (2.32.5)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15.0)
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15.0)
#   Downloading werkzeug-3.1.8-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /opt/homebrew/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15.0) (6.2.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/homebrew/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15.0) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/homebrew/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15.0) (4.9.1)
# Collecting google-auth<3,>=1.6.3 (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15.0)
#   Downloading google_auth-2.55.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15.0)
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting cryptography>=38.0.3 (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15.0)
#   Downloading cryptography-49.0.0-cp39-abi3-macosx_11_0_arm64.whl.metadata (4.3 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/homebrew/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15.0) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15.0) (2025.11.12)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/homebrew/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow-macos==2.15.0->tensorflow==2.15.0) (0.45.1)
# Collecting cffi>=2.0.0 (from cryptography>=38.0.3->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15.0)
#   Using cached cffi-2.0.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (2.6 kB)
# Collecting pycparser (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15.0)
#   Downloading pycparser-3.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /opt/homebrew/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15.0) (0.6.1)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15.0)
#   Downloading oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Collecting markupsafe>=2.1.1 (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15.0)
#   Using cached markupsafe-3.0.3-cp310-cp310-macosx_11_0_arm64.whl.metadata (2.7 kB)
# Downloading tensorflow-2.15.0-cp310-cp310-macosx_12_0_arm64.whl (2.1 kB)
# Downloading tensorflow_macos-2.15.0-cp310-cp310-macosx_12_0_arm64.whl (208.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.8/208.8 MB 3.8 MB/s  0:01:02m0:00:0100:02
# Downloading grpcio-1.81.1-cp310-cp310-macosx_11_0_universal2.whl (12.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 9.5 MB/s  0:00:01m0:00:010:01m
# Downloading keras-2.15.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 10.1 MB/s  0:00:00
# Downloading ml_dtypes-0.2.0-cp310-cp310-macosx_10_9_universal2.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 3.5 MB/s  0:00:00 eta 0:00:01
# Using cached numpy-1.26.4-cp310-cp310-macosx_11_0_arm64.whl (14.0 MB)
# Downloading protobuf-4.25.9-cp37-abi3-macosx_10_9_universal2.whl (394 kB)
# Downloading tensorboard-2.15.2-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 8.1 MB/s  0:00:00 eta 0:00:01
# Downloading google_auth_oauthlib-1.4.0-py3-none-any.whl (19 kB)
# Downloading google_auth-2.55.1-py3-none-any.whl (252 kB)
# Using cached tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl (441 kB)
# Downloading wrapt-1.14.2-cp310-cp310-macosx_11_0_arm64.whl (35 kB)
# Downloading absl_py-2.4.0-py3-none-any.whl (135 kB)
# Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading cryptography-49.0.0-cp39-abi3-macosx_11_0_arm64.whl (4.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 8.6 MB/s  0:00:00 eta 0:00:01m
# Using cached cffi-2.0.0-cp310-cp310-macosx_11_0_arm64.whl (180 kB)
# Downloading flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Downloading gast-0.7.0-py3-none-any.whl (22 kB)
# Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading h5py-3.16.0-cp310-cp310-macosx_11_0_arm64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 10.2 MB/s  0:00:00 eta 0:00:01
# Using cached libclang-18.1.1-1-py2.py3-none-macosx_11_0_arm64.whl (25.8 MB)
# Downloading markdown-3.10.2-py3-none-any.whl (108 kB)
# Using cached opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Downloading oauthlib-3.3.1-py3-none-any.whl (160 kB)
# Using cached tensorflow_io_gcs_filesystem-0.37.1-cp310-cp310-macosx_12_0_arm64.whl (3.5 MB)
# Downloading termcolor-3.3.0-py3-none-any.whl (7.7 kB)
# Downloading werkzeug-3.1.8-py3-none-any.whl (226 kB)
# Using cached markupsafe-3.0.3-cp310-cp310-macosx_11_0_arm64.whl (12 kB)
# Downloading pycparser-3.0-py3-none-any.whl (48 kB)
# Installing collected packages: libclang, flatbuffers, wrapt, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, pycparser, protobuf, opt-einsum, oauthlib, numpy, markupsafe, markdown, keras, grpcio, google-pasta, gast, astunparse, absl-py, werkzeug, requests-oauthlib, ml-dtypes, h5py, cffi, cryptography, google-auth, google-auth-oauthlib, tensorboard, tensorflow-macos, tensorflow
#   Attempting uninstall: numpy╸━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/31 [oauthlib]w-estimator]
#     Found existing installation: numpy 2.2.6━━━━━━━━━━━━━━━━━━ 10/31 [oauthlib]
#     Uninstalling numpy-2.2.6:m━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/31 [oauthlib]
#       Successfully uninstalled numpy-2.2.6━━━━━━━━━━━━━━━━━━━━ 10/31 [oauthlib]
#   Attempting uninstall: google-auth━━━╸━━━━━━━━━ 24/31 [cffi]py]
#     Found existing installation: google-auth 2.43.00m━━━━━━━━━ 24/31 [cffi]
#     Uninstalling google-auth-2.43.0:0m╸━━━━━━━━━ 24/31 [cffi]
#       Successfully uninstalled google-auth-2.43.0━━━━━━━━━ 24/31 [cffi]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31/31 [tensorflow]1 [tensorflow-macos]
# Successfully installed absl-py-2.4.0 astunparse-1.6.3 cffi-2.0.0 cryptography-49.0.0 flatbuffers-25.12.19 gast-0.7.0 google-auth-2.55.1 google-auth-oauthlib-1.4.0 google-pasta-0.2.0 grpcio-1.81.1 h5py-3.16.0 keras-2.15.0 libclang-18.1.1 markdown-3.10.2 markupsafe-3.0.3 ml-dtypes-0.2.0 numpy-1.26.4 oauthlib-3.3.1 opt-einsum-3.4.0 protobuf-4.25.9 pycparser-3.0 requests-oauthlib-2.0.0 tensorboard-2.15.2 tensorboard-data-server-0.7.2 tensorflow-2.15.0 tensorflow-estimator-2.15.0 tensorflow-io-gcs-filesystem-0.37.1 tensorflow-macos-2.15.0 termcolor-3.3.0 werkzeug-3.1.8 wrapt-1.14.2
#
# [notice] A new release of pip is available: 25.2 -> 26.1.2
# [notice] To update, run: /opt/homebrew/opt/python@3.10/bin/python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip uninstall -y tensorflow tensorflow-macos tensorflow-metal
pip uninstall -y numpy
# Out:
#   Cell In[7], line 1
#     pip uninstall -y tensorflow tensorflow-macos tensorflow-metal
#         ^
# SyntaxError: invalid syntax

# %%
pip install "numpy==1.26.4"
# Out:
# Requirement already satisfied: numpy==1.26.4 in /opt/homebrew/lib/python3.10/site-packages (1.26.4)
#
# [notice] A new release of pip is available: 25.2 -> 26.1.2
# [notice] To update, run: /opt/homebrew/opt/python@3.10/bin/python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Conv2D, MaxPooling2D, Flatten,
    Dense, Dropout, BatchNormalization
)
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 5
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 5 import tensorflow as tf
#       6 from tensorflow.keras.preprocessing.image import ImageDataGenerator
#       7 from tensorflow.keras.models import Sequential
#
# File /opt/homebrew/lib/python3.10/site-packages/tensorflow/__init__.py:48
#      45 from tensorflow.python import tf2 as _tf2
#      46 _tf2.enable()
# ---> 48 from tensorflow._api.v2 import __internal__
#      49 from tensorflow._api.v2 import __operators__
#      50 from tensorflow._api.v2 import audio
#
# File /opt/homebrew/lib/python3.10/site-packages/tensorflow/_api/v2/__internal__/__init__.py:8
#       3 """Public API for tf._api.v2.__internal__ namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow._api.v2.__internal__ import autograph
#       9 from tensorflow._api.v2.__internal__ import decorator
#      10 from tensorflow._api.v2.__internal__ import dispatch
#
# File /opt/homebrew/lib/python3.10/site-packages/tensorflow/_api/v2/__internal__/autograph/__init__.py:8
#       3 """Public API for tf._api.v2.__internal__.autograph namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow.python.autograph.core.ag_ctx import control_status_ctx # line: 34
#       9 from tensorflow.python.autograph.impl.api import tf_convert # line: 493
#
# File /opt/homebrew/lib/python3.10/site-packages/tensorflow/python/autograph/core/ag_ctx.py:21
#      18 import inspect
#      19 import threading
# ---> 21 from tensorflow.python.autograph.utils import ag_logging
#      22 from tensorflow.python.util.tf_export import tf_export
#      25 stacks = threading.local()
#
# File /opt/homebrew/lib/python3.10/site-packages/tensorflow/python/autograph/utils/__init__.py:17
#       1 # Copyright 2016 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Utility module that contains APIs usable in the generated code."""
# ---> 17 from tensorflow.python.autograph.utils.context_managers import control_dependency_on_returns
#      18 from tensorflow.python.autograph.utils.misc import alias_tensors
#      19 from tensorflow.python.autograph.utils.tensor_list import dynamic_list_append
#
# File /opt/homebrew/lib/python3.10/site-packages/tensorflow/python/autograph/utils/context_managers.py:19
#      15 """Various context managers."""
#      17 import contextlib
# ---> 19 from tensorflow.python.framework import ops
#      20 from tensorflow.python.ops import tensor_array_ops
#      23 def control_dependency_on_returns(return_value):
#
# File /opt/homebrew/lib/python3.10/site-packages/tensorflow/python/framework/ops.py:57
#      55 from tensorflow.python.framework import registry
#      56 from tensorflow.python.framework import stack
# ---> 57 from tensorflow.python.framework import tensor as tensor_lib
#      58 from tensorflow.python.framework import tensor_conversion_registry
#      59 from tensorflow.python.framework import tensor_shape
#
# File /opt/homebrew/lib/python3.10/site-packages/tensorflow/python/framework/tensor.py:35
#      33 from tensorflow.python.framework import tensor_conversion_registry
#      34 from tensorflow.python.framework import tensor_shape
# ---> 35 from tensorflow.python.framework import tensor_util
#      36 from tensorflow.python.framework import type_spec
#      37 from tensorflow.python.framework import type_spec_registry
#
# File /opt/homebrew/lib/python3.10/site-packages/tensorflow/python/framework/tensor_util.py:35
#      32 # Fallback in case fast_tensor_util is not properly compiled.
#      33 # pylint: disable=g-import-not-at-top
#      34 try:
# ---> 35   from tensorflow.python.framework import fast_tensor_util
#      36   _FAST_TENSOR_UTIL_AVAILABLE = True
#      37 except ImportError:
#
# File tensorflow/python/framework/fast_tensor_util.pyx:1, in init tensorflow.python.framework.fast_tensor_util()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject
